# %%
import os
import pyktok as pyk

pyk.specify_browser("edge")

tiktok_videos = [
    'https://www.tiktok.com/@noemistore21/video/7517856534718729478?q=CREMA%20HIDRATANTE%20DE%20MARACUYA%20EKOS%20-%2075%20GR&t=1769194303888',
    'https://www.tiktok.com/@natura.bo/video/7397048364971412742?q=CREMA%20HIDRATANTE%20DE%20MARACUYA%20EKOS%20-%2075%20GR&t=1769194303888',
    'https://www.tiktok.com/@miich_ugc/video/7306292052323536134?q=CREMA%20HIDRATANTE%20DE%20MARACUYA%20EKOS%20-%2075%20GR&t=1769194303888',
]

pyk.save_tiktok_multi_urls(
    tiktok_videos,
    True,
    'data.csv',
    2
)
# Out:
# If pyktok does not operate as expected, you may find it helpful to run the 'specify_browser' function. 'specify_browser' takes as its sole argument a string representing a browser installed on your system, e.g. "chrome," "firefox," "edge," etc.
# Saved video
#  https://www.tiktok.com/@noemistore21/video/7517856534718729478?q=CREMA%20HIDRATANTE%20DE%20MARACUYA%20EKOS%20-%2075%20GR&t=1769194303888
# to
#  /home/tobi/Desktop/repos/Denisse/libs
# Saved metadata for video
#  https://www.tiktok.com/@noemistore21/video/7517856534718729478?q=CREMA%20HIDRATANTE%20DE%20MARACUYA%20EKOS%20-%2075%20GR&t=1769194303888
# to
#  /home/tobi/Desktop/repos/Denisse/libs
# Saved video
#  https://www.tiktok.com/@natura.bo/video/7397048364971412742?q=CREMA%20HIDRATANTE%20DE%20MARACUYA%20EKOS%20-%2075%20GR&t=1769194303888
# to
#  /home/tobi/Desktop/repos/Denisse/libs
# Saved metadata for video
# ...
